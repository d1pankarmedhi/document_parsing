# %% [markdown]
# # Parsing documents into HTML

# %%
from langchain_community.document_loaders import PDFMinerPDFasHTMLLoader
import os

# %%
loader = PDFMinerPDFasHTMLLoader(os.path.join(os.getcwd(), "documents", "document_2.pdf") )
data = loader.load()[0]   # entire PDF is loaded as a single Document

# save to a html file
file_name = 'content.html'
file_path = os.path.join(os.getcwd(), file_name)
with open(file_path, "w") as f:
    f.write(data.page_content)

print(data.page_content[:1000])
# Out:
# <html><head>
# <meta http-equiv="Content-Type" content="text/html">
# </head><body>
# <span style="position:absolute; border: gray 1px solid; left:0px; top:50px; width:612px; height:792px;"></span>
# <div style="position:absolute; top:50px;"><a name="1">Page 1</a></div>
# <div style="position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:46px; top:173px; width:119px; height:37px;"><span style="font-family: Helvetica-Bold; font-size:21px">Tesla Inc.
# <br></span><span style="font-family: Helvetica-Bold; font-size:14px">(NASDAQ: TSLA)
# <br></span></div><div style="position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:46px; top:227px; width:98px; height:15px;"><span style="font-family: Helvetica-Bold; font-size:15px">Fully Valued
# <br></span></div><div style="position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:471px; top:108px; width:70px; height:12px;"><span style="font-family: Helvetica-Bold; font-size:12px">May 2, 2023
# <br></span></div><div st

# %% [markdown]
# ## Segmenting Tags and Contents

# %%
import re
def extract_tags(data):
    pattern = re.compile(r'<[\w+?+]>|<(\w+?)\b')
    matches = pattern.findall(data)
    
    return set(matches)

print(f"INFO avaliable tags from document:")
tags = extract_tags(data.page_content)
print(f"Tags: {tags}")
# Out:
# INFO avaliable tags from document:
# Tags: {'html', 'meta', 'div', 'a', 'br', 'body', 'head', 'span'}

# %% [markdown]
# ## Html parsing with BeautifulSoup

# %%
from bs4 import BeautifulSoup

def extract_content_for_tags(page_content, tags):
    soup = BeautifulSoup(page_content, 'html.parser')

    content_for_tags = {}
    for tag in tags:
        tag_occurrences = soup.find_all(tag)
        
        content_list = []
        for occurrence in tag_occurrences:
            content_list.append(occurrence.get_text())
        
        content_for_tags[tag] = content_list
    
    return content_for_tags

content_for_tags = extract_content_for_tags(data.page_content, tags)
for k, v in content_for_tags.items():
    print(f"{k}")
    print(f"{v}")
# Out:
# html
# ['\n\n\n\nPage 1\nTesla Inc.  \n(NASDAQ: TSLA) \nFully Valued \nMay 2, 2023 \nSid Rajeev, B.Tech, CFA, MBA \nHead of Research  \nAlexis Cabel, BAEcon \nEquity Analyst \nSector/Industry: Auto Manufacturers                        Click here for more research on the company and to share your views  \nHighlights\n➢\nIn Q1-2023, TSLA’s revenue rose 24% YoY, beating our estimate by 6%, due to stronger than expected \nsales. However, EPS fell 23% YoY (2% below our forecast) due to margin erosion (gross margins were \ndown 10 ppt YoY) from higher raw material/manufacturing/logistics costs, and as Tesla has been slashing \nvehicle prices (down 9% YoY).  \n➢ TSLA is down 53% since our initiating report in April 2022, wherein we had predicted 39% downside \nrisk.\n➢ According to the  International Energy Agency (IEA), 10.3M Electric Vehicles (EV) were sold in 2022 (up \n49% YoY, accounting for 14% of global vehicle sales). The IEA is forecasting 35% YoY growth in 2023, \naccounting for 18% of global vehicle sales.\n➢ Tesla sold 0.42M vehicles in Q1-2023, or 13% of the largest auto manufacturer (Toyota/TSE: 7203), 13% \nof global EV sales, and 2% of global vehicle sales. Yet, Tesla remains the largest auto manufacturer by \nMCAP ($513B) – 2.8x Toyota’s MCAP ($186B).   \n➢ We are continuing to run our valuation models assuming Tesla will capture 40% of the global EV market \n(12%  of  global  auto  sales)  by  2030.  However,  due  to the reasons mentioned  above,  we  are  lowing  our \nmargin forecasts. Our revised DCF valuation is $157/share (previously $207/share), which is 3% below \nthe current share price of $162.\n➢ We believe the current share price reflects an implied market share of 41% of EV sales (12% of global \nauto sales) by 2030. For comparison, Toyota’s current share is 16% of global sales.  \n➢ Our fair value estimate is 23% below the consensus estimate of $203/share (range: $115 to $300/share). \n15 out of 31 analysts have a BUY rating (Source: TipRanks).  \n➢ Our  valuation  ranges  between  $32  and  $332  per  share,  when  we  adjust  our  2030  EV-market  share \nforecast from 15% to 75%.  \n➢ As most of the legacy automakers have long track records, and are spending heavily on their EV initiatives, \nwe are expecting stiff competition, and do not believe Tesla will be able to dominate the market over the \nlong-term.  \n➢ Based on our revised fair value estimate of $157/share, we believe the shares are fully valued. \n*See last page for important disclosures, rating, and risk definitions. All figures in US$ unless otherwise specified. \n©2023 Fundamental Research Corp.           “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”            www.researchfrc.com                \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPage 2\nEquity Research – Initiating Report\nPage 2 of 7 \nOverview and Track Record \nVehicle Sales and Growth Rate  \nFounded in 2003 \nStarted generating \nmeaningful revenue \nin 2009 \nFrom 2009 to 2022, \nvehicle sales grew \nat a CAGR of 75% \nIn Q1-2023, sales \nwere up 36% YoY, \nto 423M units  \nFrom 2009 to 2022, \nrevenue grew 66% \np.a. \nSource: FRC / Company Fillings \nRevenue \n©2023 Fundamental Research Corp.            “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”    www.researchfrc.com\nSource: Company \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPage 3\nEquity Research – Initiating Report\nPage 3 of 7 \nTesla vs The Top Five Legacy Auto Makers \nVehicle Sales (2022) \nIn 2022, Tesla’s \nsales were 13% (9% \nin 2021) of the \nworld’s largest car \nmanufacturer \n(Toyota), and 33% \n(14% in 2021) of the \nfifth largest \n(Hyundai/KOSE: \nA005380)  \nTesla’s reve ...
# meta
# ['']
# div
# ['Page 1', 'Tesla Inc.  \n(NASDAQ: TSLA) \n', 'Fully Valued \n', 'May 2, 2023 \n', 'Sid Rajeev, B.Tech, CFA, MBA \nHead of Research  \n', 'Alexis Cabel, BAEcon \nEquity Analyst \n', 'Sector/Industry: Auto Manufacturers                        Click here for more research on the company and to share your views  \n', 'Highlights\n➢\n', 'In Q1-2023, TSLA’s revenue rose 24% YoY, beating our estimate by 6%, due to stronger than expected \nsales. However, EPS fell 23% YoY (2% below our forecast) due to margin erosion (gross margins were \ndown 10 ppt YoY) from higher raw material/manufacturing/logistics costs, and as Tesla has been slashing \nvehicle prices (down 9% YoY).  \n', '➢ TSLA is down 53% since our initiating report in April 2022, wherein we had predicted 39% downside \n', 'risk.\n', '➢ According to the  International Energy Agency (IEA), 10.3M Electric Vehicles (EV) were sold in 2022 (up \n49% YoY, accounting for 14% of global vehicle sales). The IEA is forecasting 35% YoY growth in 2023, \naccounting for 18% of global vehicle sales.\n', '➢ Tesla sold 0.42M vehicles in Q1-2023, or 13% of the largest auto manufacturer (Toyota/TSE: 7203), 13% \nof global EV sales, and 2% of global vehicle sales. Yet, Tesla remains the largest auto manufacturer by \nMCAP ($513B) – 2.8x Toyota’s MCAP ($186B).   \n', '➢ We are continuing to run our valuation models assuming Tesla will capture 40% of the global EV market \n(12%  of  global  auto  sales)  by  2030.  However,  due  to the reasons mentioned  above,  we  are  lowing  our \nmargin forecasts. Our revised DCF valuation is $157/share (previously $207/share), which is 3% below \nthe current share price of $162.\n', '➢ We believe the current share price reflects an implied market share of 41% of EV sales (12% of global \n', 'auto sales) by 2030. For comparison, Toyota’s current share is 16% of global sales.  \n', '➢ Our fair value estimate is 23% below the consensus estimate of $203/share (range: $115 to $300/share). \n', '15 out of 31 analysts have a BUY rating (Source: TipRanks).  \n', '➢ Our  valuation  ranges  between  $32  and  $332  per  share,  when  we  adjust  our  2030  EV-market  share \n', 'forecast from 15% to 75%.  \n', '➢ As most of the legacy automakers have long track records, and are spending heavily on their EV initiatives, \nwe are expecting stiff competition, and do not believe Tesla will be able to dominate the market over the \nlong-term.  \n', '➢ Based on our revised fair value estimate of $157/share, we believe the shares are fully valued. \n', '*See last page for important disclosures, rating, and risk definitions. All figures in US$ unless otherwise specified. \n', '©2023 Fundamental Research Corp.           “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”            www.researchfrc.com                \n', '', 'Page 2', 'Equity Research – Initiating Report\nPage 2 of 7 \n', 'Overview and Track Record \n', 'Vehicle Sales and Growth Rate  \n', 'Founded in 2003 \n', 'Started generating \nmeaningful revenue \nin 2009 \n', 'From 2009 to 2022, \nvehicle sales grew \nat a CAGR of 75% \n', 'In Q1-2023, sales \nwere up 36% YoY, \nto 423M units  \n', 'From 2009 to 2022, \nrevenue grew 66% \np.a. \n', 'Source: FRC / Company Fillings \n', 'Revenue \n', '©2023 Fundamental Research Corp.            “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”    www.researchfrc.com\n', 'Source: Company \n', '', '', '', '', '', 'Page 3', 'Equity Research – Initiating Report\nPage 3 of 7 \n', 'Tesla vs The Top Five Legacy Auto Makers \n', 'Vehicle Sales (2022) \n', 'In 2022, Tesla’s \nsales were 13% (9% \nin 2021) of the \nworld’s largest car \nmanufacturer \n(Toyota), and 33% \n(14% in 2021) of the \nfifth largest \n(Hyundai/KOSE: \nA005380)  \n', 'Tesla’s revenue is \nlower than the top \nfive legacy \nautomakers \n', 'Revenue (Last 12 Months) \n', 'Source: FRC / Company Fillings / S&P Capital IQ / Various Sources \n', '©2023 Fund ...
# a
# ['Page 1', 'Page 2', 'Page 3', 'Page 4', 'Page 5', 'Page 6', 'Page 7', '1', '2', '3', '4', '5', '6', '7']
# br
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# body
# ['\n\nPage 1\nTesla Inc.  \n(NASDAQ: TSLA) \nFully Valued \nMay 2, 2023 \nSid Rajeev, B.Tech, CFA, MBA \nHead of Research  \nAlexis Cabel, BAEcon \nEquity Analyst \nSector/Industry: Auto Manufacturers                        Click here for more research on the company and to share your views  \nHighlights\n➢\nIn Q1-2023, TSLA’s revenue rose 24% YoY, beating our estimate by 6%, due to stronger than expected \nsales. However, EPS fell 23% YoY (2% below our forecast) due to margin erosion (gross margins were \ndown 10 ppt YoY) from higher raw material/manufacturing/logistics costs, and as Tesla has been slashing \nvehicle prices (down 9% YoY).  \n➢ TSLA is down 53% since our initiating report in April 2022, wherein we had predicted 39% downside \nrisk.\n➢ According to the  International Energy Agency (IEA), 10.3M Electric Vehicles (EV) were sold in 2022 (up \n49% YoY, accounting for 14% of global vehicle sales). The IEA is forecasting 35% YoY growth in 2023, \naccounting for 18% of global vehicle sales.\n➢ Tesla sold 0.42M vehicles in Q1-2023, or 13% of the largest auto manufacturer (Toyota/TSE: 7203), 13% \nof global EV sales, and 2% of global vehicle sales. Yet, Tesla remains the largest auto manufacturer by \nMCAP ($513B) – 2.8x Toyota’s MCAP ($186B).   \n➢ We are continuing to run our valuation models assuming Tesla will capture 40% of the global EV market \n(12%  of  global  auto  sales)  by  2030.  However,  due  to the reasons mentioned  above,  we  are  lowing  our \nmargin forecasts. Our revised DCF valuation is $157/share (previously $207/share), which is 3% below \nthe current share price of $162.\n➢ We believe the current share price reflects an implied market share of 41% of EV sales (12% of global \nauto sales) by 2030. For comparison, Toyota’s current share is 16% of global sales.  \n➢ Our fair value estimate is 23% below the consensus estimate of $203/share (range: $115 to $300/share). \n15 out of 31 analysts have a BUY rating (Source: TipRanks).  \n➢ Our  valuation  ranges  between  $32  and  $332  per  share,  when  we  adjust  our  2030  EV-market  share \nforecast from 15% to 75%.  \n➢ As most of the legacy automakers have long track records, and are spending heavily on their EV initiatives, \nwe are expecting stiff competition, and do not believe Tesla will be able to dominate the market over the \nlong-term.  \n➢ Based on our revised fair value estimate of $157/share, we believe the shares are fully valued. \n*See last page for important disclosures, rating, and risk definitions. All figures in US$ unless otherwise specified. \n©2023 Fundamental Research Corp.           “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”            www.researchfrc.com                \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPage 2\nEquity Research – Initiating Report\nPage 2 of 7 \nOverview and Track Record \nVehicle Sales and Growth Rate  \nFounded in 2003 \nStarted generating \nmeaningful revenue \nin 2009 \nFrom 2009 to 2022, \nvehicle sales grew \nat a CAGR of 75% \nIn Q1-2023, sales \nwere up 36% YoY, \nto 423M units  \nFrom 2009 to 2022, \nrevenue grew 66% \np.a. \nSource: FRC / Company Fillings \nRevenue \n©2023 Fundamental Research Corp.            “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”    www.researchfrc.com\nSource: Company \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPage 3\nEquity Research – Initiating Report\nPage 3 of 7 \nTesla vs The Top Five Legacy Auto Makers \nVehicle Sales (2022) \nIn 2022, Tesla’s \nsales were 13% (9% \nin 2021) of the \nworld’s largest car \nmanufacturer \n(Toyota), and 33% \n(14% in 2021) of the \nfifth largest \n(Hyundai/KOSE: \nA005380)  \nTesla’s revenue  ...
# head
# ['\n\n']
# span
# ['', 'Tesla Inc.  \n', '(NASDAQ: TSLA) \n', 'Fully Valued \n', 'May 2, 2023 \n', 'Sid Rajeev, B.Tech, CFA, MBA \n', 'Head of Research  \n', 'Alexis Cabel, BAEcon \n', 'Equity Analyst \n', 'Sector/Industry: Auto Manufacturers                        ', 'Click here for more research on the company and to share your views  \n', 'Highlights', '\n', '➢', '\n', 'In Q1-2023, ', 'TSLA’s ', 'revenue rose 24% YoY, beating our estimate by 6%, due to stronger than expected \nsales. However, ', 'EPS fell 23% YoY (2% below our forecast)', ' due to margin erosion (gross margins were \n', 'down 10 ppt YoY) from higher raw material/manufacturing/logistics costs, and as Tesla has been slashing \nvehicle prices (down 9% YoY).  \n', '➢', ' ', 'TSLA is down 53% since our initiating report in April 2022, wherein we had predicted 39% downside \n', 'risk.', '\n', '➢', ' ', 'According to the  International Energy Agency (IEA), 10.3M Electric Vehicles (EV) were sold in 2022 (up \n49% YoY, accounting for 14% of global vehicle sales). ', 'The IEA is forecasting 35% YoY growth in 2023, \naccounting for 18% of global vehicle sales.', '\n', '➢', ' ', 'Tesla sold 0.42M vehicles in Q1-2023, or 13% of the largest auto manufacturer (Toyota/TSE: 7203), 13% \nof global EV sales, and 2% of global vehicle sales. Yet, Tesla remains the ', 'largest auto manufacturer by \nMCAP', ' ($513B) ', '–', ' 2.8x ', 'Toyota’s MCAP ', '($186B).   \n', '➢', ' ', 'We are continuing to run our valuation models assuming Tesla will capture 40% of the global EV market \n(12%  of  global  auto  sales)  by  2030.  However,  due  to the reasons mentioned  above,  we  are  lowing  our \nmargin forecasts. Our revised DCF valuation is', ' $157/share (previously $207/share), which is 3% below \nthe current share price of $162.', '\n', '➢', ' ', 'We believe the current share price reflects an', ' implied market share of 41% of EV sales (12% of global \n', 'auto sales) by 2030.', ' For comparison, ', 'Toyota’s ', 'current share is 16% of global sales.  \n', '➢', ' ', 'Our fair value estimate is 23% below the consensus estimate of $203/share (range: $115 to $300/share). \n', '15 out of 31 analysts have a BUY rating (Source: TipRanks).  \n', '➢', ' ', 'Our  ', 'valuation  ranges  between  $32  and  $332  per  share', ',  when  we  adjust  our  2030  EV-market  share \n', 'forecast from 15% to 75%.  \n', '➢', ' ', 'As most of the legacy automakers have long track records, and are spending heavily on their EV initiatives, \n', 'we are expecting stiff competition, and do not believe Tesla will be able to dominate the market over the \n', 'long-term.  \n', '➢', ' ', 'Based on our revised fair value estimate of $157/share, we believe the shares are fully valued.', ' ', '\n', '*See last page for important disclosures, rating, and risk definitions. All figures in US$ unless otherwise specified. \n', '©', '2023 Fundamental Research Corp.           ', '“1', '9+ Years of Bringing Undiscovered Investment Opportunities to the Forefront', '”        ', '    www.researchfrc.com                \n', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n\n', '\n', '\n\n', '\n\n', '\n\n', '\n\n\n\n\n\n', '\n\n', '\n', '\n\nPage 2\nEquity Research – Initiating Report\nPage 2 of 7 \nOverview and Track Record \nVehicle Sales and Growth Rate  \nFounded in 2003 \nStarted generating \nmeaningful revenue \nin 2009 \nFrom 2009 to 2022, \nvehicle sales grew \nat a CAGR of 75% \nIn Q1-2023, sales \nwere up 36% YoY, \nto 423M units  \nFrom 2009 to 2022, \nrevenue grew 66% \np.a. \nSource: FRC / Company Fillings \nRevenue \n©2023 Fundamental Research Corp.            “19+ Years of Bringing Undiscovered Investment Opportunities to the Forefront”    www.researchfrc.com\nSource: Company \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n ...

# %% [markdown]
# The content is distributed across various tags so it is difficult to identify the most important segment.
# One must have some domain knowledge to find which portion is relevant to the problem statement.
#
# One brute force solution can be to feed the data into LLM and let it figure out the important itself but that is not an efficient solution due to the token limitations.
